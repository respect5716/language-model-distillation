# %%
import hydra
from omegaconf import OmegaConf

# %%
with hydra.initialize(config_path='../configs'):
    cfg = hydra.compose('config')
    print(cfg)
# Out:
# {'data': {'data_dir': '${data_dir}', 'batch_size': 16, 'num_workers': 8, 'pin_memory': False, 'name': 'text', 'datasets': ['namuwiki', 'modu_spoken', 'modu_written', 'modu_newspaper']}, 'model': {'teacher': {'architecture': 'klue/bert-base'}, 'student': {'num_hidden_layers': 6, 'hidden_size': 384}}, 'trainer': {'gpus': -1, 'max_steps': 100000, 'progress_bar_refresh_rate': 10, 'resume_from_checkpoint': None, 'num_sanity_val_steps': 10}, 'working_dir': '${hydra:runtime.cwd}', 'data_dir': '${working_dir}/../data'}
# /usr/local/lib/python3.8/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'config': Defaults list is missing `_self_`. See https://hydra.cc/docs/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)

# %%
print(OmegaConf.to_yaml(cfg))
# Out:
# data:
#   data_dir: ${data_dir}
#   batch_size: 16
#   num_workers: 8
#   pin_memory: false
#   name: text
#   datasets:
#   - namuwiki
#   - modu_spoken
#   - modu_written
#   - modu_newspaper
# model:
#   teacher:
#     architecture: klue/bert-base
#   student:
#     num_hidden_layers: 6
#     hidden_size: 384
# trainer:
#   gpus: -1
#   max_steps: 100000
#   progress_bar_refresh_rate: 10
#   resume_from_checkpoint: null
#   num_sanity_val_steps: 10
# working_dir: ${hydra:runtime.cwd}
# data_dir: ${working_dir}/../data

# %%
cfg.data_dir
# Out:
# ---------------------------------------------------------------------------
# InterpolationResolutionError              Traceback (most recent call last)
# /tmp/ipykernel_4626/4259884814.py in <module>
# ----> 1 cfg.data_dir
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/dictconfig.py in __getattr__(self, key)
#     355             )
#     356         except Exception as e:
# --> 357             self._format_and_raise(key=key, value=None, cause=e)
#     358
#     359     def __getitem__(self, key: DictKeyType) -> Any:
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in _format_and_raise(self, key, value, cause, type_override)
#     188         self, key: Any, value: Any, cause: Exception, type_override: Any = None
#     189     ) -> None:
# --> 190         format_and_raise(
#     191             node=self,
#     192             key=key,
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/_utils.py in format_and_raise(node, key, value, msg, cause, type_override)
#     819         ex.ref_type_str = ref_type_str
#     820
# --> 821     _raise(ex, cause)
#     822
#     823
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/_utils.py in _raise(ex, cause)
#     717     else:
#     718         ex.__cause__ = None
# --> 719     raise ex.with_traceback(sys.exc_info()[2])  # set end OC_CAUSE=1 for full backtrace
#     720
#     721
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/dictconfig.py in __getattr__(self, key)
#     349
#     350         try:
# --> 351             return self._get_impl(key=key, default_value=_DEFAULT_MARKER_)
#     352         except ConfigKeyError as e:
#     353             self._format_and_raise(
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/dictconfig.py in _get_impl(self, key, default_value)
#     443                 raise
#     444         assert isinstance(node, Node)
# --> 445         return self._resolve_with_default(
#     446             key=key, value=node, default_value=default_value
#     447         )
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/basecontainer.py in _resolve_with_default(self, key, value, default_value)
#      63             raise MissingMandatoryValue("Missing mandatory value: $FULL_KEY")
#      64
# ---> 65         resolved_node = self._maybe_resolve_interpolation(
#      66             parent=self,
#      67             key=key,
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in _maybe_resolve_interpolation(self, parent, key, value, throw_on_resolution_failure, memo)
#     614
#     615         parse_tree = parse(_get_value(value))
# --> 616         return self._resolve_interpolation_from_parse_tree(
#     617             parent=parent,
#     618             value=value,
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in _resolve_interpolation_from_parse_tree(self, parent, value, key, parse_tree, throw_on_resolution_failure, memo)
#     480
#     481         try:
# --> 482             resolved = self.resolve_parse_tree(
#     483                 parse_tree=parse_tree, node=value, key=key, parent=parent, memo=memo
#     484             )
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     660         )
#     661         try:
# --> 662             return visitor.visit(parse_tree)
#     663         except InterpolationResolutionError:
#     664             raise
#
# /usr/local/lib/python3.8/dist-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py in accept(self, visitor)
#     203         def accept(self, visitor:ParseTreeVisitor):
#     204             if hasattr( visitor, "visitConfigValue" ):
# --> 205                 return visitor.visitConfigValue(self)
#     206             else:
#     207                 return visitor.visitChildren(self)
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar_visitor.py in visitConfigValue(self, ctx)
#      99         # text EOF
#     100         assert ctx.getChildCount() == 2
# --> 101         return self.visit(ctx.getChild(0))
#     102
#     103     def visitDictKey(self, ctx: OmegaConfGrammarParser.DictKeyContext) -> Any:
#
# /usr/local/lib/python3.8/dist-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py in accept(self, visitor)
#     337         def accept(self, visitor:ParseTreeVisitor):
#     338             if hasattr( visitor, "visitText" ):
# --> 339                 return visitor.visitText(self)
#     340             else:
#     341                 return visitor.visitChildren(self)
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar_visitor.py in visitText(self, ctx)
#     299
#     300         # Otherwise, concatenate string representations together.
# --> 301         return self._unescape(list(ctx.getChildren()))
#     302
#     303     def _createPrimitive(
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar_visitor.py in _unescape(self, seq)
#     387             else:
#     388                 assert isinstance(node, OmegaConfGrammarParser.InterpolationContext)
# --> 389                 text = str(self.visitInterpolation(node))
#     390             chrs.append(text)
#     391
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar_visitor.py in visitInterpolation(self, ctx)
#     123     ) -> Any:
#     124         assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125         return self.visit(ctx.getChild(0))
#     126
#     127     def visitInterpolationNode(
#
# /usr/local/lib/python3.8/dist-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py in accept(self, visitor)
#     909         def accept(self, visitor:ParseTreeVisitor):
#     910             if hasattr( visitor, "visitInterpolationNode" ):
# --> 911                 return visitor.visitInterpolationNode(self)
#     912             else:
#     913                 return visitor.visitChildren(self)
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar_visitor.py in visitInterpolationNode(self, ctx)
#     156
#     157         inter_key = "".join(inter_key_tokens)
# --> 158         return self.node_interpolation_callback(inter_key, self.memo)
#     159
#     160     def visitInterpolationResolver(
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in node_interpolation_callback(inter_key, memo)
#     641             inter_key: str, memo: Optional[Set[int]]
#     642         ) -> Optional["Node"]:
# --> 643             return self._resolve_node_interpolation(inter_key=inter_key, memo=memo)
#     644
#     645         def resolver_interpolation_callback(
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in _resolve_node_interpolation(self, inter_key, memo)
#     559
#     560         try:
# --> 561             parent, last_key, value = root_node._select_impl(
#     562                 inter_key,
#     563                 throw_on_missing=True,
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in _select_impl(self, key, throw_on_missing, throw_on_resolution_failure, memo)
#     427
#     428         try:
# --> 429             value = root._maybe_resolve_interpolation(
#     430                 parent=root,
#     431                 key=last_key,
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in _maybe_resolve_interpolation(self, parent, key, value, throw_on_resolution_failure, memo)
#     614
#     615         parse_tree = parse(_get_value(value))
# --> 616         return self._resolve_interpolation_from_parse_tree(
#     617             parent=parent,
#     618             value=value,
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in _resolve_interpolation_from_parse_tree(self, parent, value, key, parse_tree, throw_on_resolution_failure, memo)
#     480
#     481         try:
# --> 482             resolved = self.resolve_parse_tree(
#     483                 parse_tree=parse_tree, node=value, key=key, parent=parent, memo=memo
#     484             )
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     665         except Exception as exc:
#     666             # Other kinds of exceptions are wrapped in an `InterpolationResolutionError`.
# --> 667             raise InterpolationResolutionError(
#     668                 f"{type(exc).__name__} raised while resolving interpolation: {exc}"
#     669             ).with_traceback(sys.exc_info()[2])
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in resolve_parse_tree(self, parse_tree, node, memo, key, parent)
#     660         )
#     661         try:
# --> 662             return visitor.visit(parse_tree)
#     663         except InterpolationResolutionError:
#     664             raise
#
# /usr/local/lib/python3.8/dist-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py in accept(self, visitor)
#     203         def accept(self, visitor:ParseTreeVisitor):
#     204             if hasattr( visitor, "visitConfigValue" ):
# --> 205                 return visitor.visitConfigValue(self)
#     206             else:
#     207                 return visitor.visitChildren(self)
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar_visitor.py in visitConfigValue(self, ctx)
#      99         # text EOF
#     100         assert ctx.getChildCount() == 2
# --> 101         return self.visit(ctx.getChild(0))
#     102
#     103     def visitDictKey(self, ctx: OmegaConfGrammarParser.DictKeyContext) -> Any:
#
# /usr/local/lib/python3.8/dist-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py in accept(self, visitor)
#     337         def accept(self, visitor:ParseTreeVisitor):
#     338             if hasattr( visitor, "visitText" ):
# --> 339                 return visitor.visitText(self)
#     340             else:
#     341                 return visitor.visitChildren(self)
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar_visitor.py in visitText(self, ctx)
#     296             c = ctx.getChild(0)
#     297             if isinstance(c, OmegaConfGrammarParser.InterpolationContext):
# --> 298                 return self.visitInterpolation(c)
#     299
#     300         # Otherwise, concatenate string representations together.
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar_visitor.py in visitInterpolation(self, ctx)
#     123     ) -> Any:
#     124         assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125         return self.visit(ctx.getChild(0))
#     126
#     127     def visitInterpolationNode(
#
# /usr/local/lib/python3.8/dist-packages/antlr4/tree/Tree.py in visit(self, tree)
#      32 class ParseTreeVisitor(object):
#      33     def visit(self, tree):
# ---> 34         return tree.accept(self)
#      35
#      36     def visitChildren(self, node):
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py in accept(self, visitor)
#    1028         def accept(self, visitor:ParseTreeVisitor):
#    1029             if hasattr( visitor, "visitInterpolationResolver" ):
# -> 1030                 return visitor.visitInterpolationResolver(self)
#    1031             else:
#    1032                 return visitor.visitChildren(self)
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/grammar_visitor.py in visitInterpolationResolver(self, ctx)
#     177                 args_str.append(txt)
#     178
# --> 179         return self.resolver_interpolation_callback(
#     180             name=resolver_name,
#     181             args=tuple(args),
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in resolver_interpolation_callback(name, args, args_str)
#     646             name: str, args: Tuple[Any, ...], args_str: Tuple[str, ...]
#     647         ) -> Any:
# --> 648             return self._evaluate_custom_resolver(
#     649                 key=key,
#     650                 node=node,
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/base.py in _evaluate_custom_resolver(self, key, node, inter_type, inter_args, inter_args_str)
#     589         if resolver is not None:
#     590             root_node = self._get_root()
# --> 591             return resolver(
#     592                 root_node,
#     593                 self,
#
# /usr/local/lib/python3.8/dist-packages/omegaconf/omegaconf.py in resolver_wrapper(config, parent, node, args, args_str)
#     433                 kwargs["_root_"] = config
#     434
# --> 435             ret = resolver(*args, **kwargs)
#     436
#     437             if use_cache:
#
# /usr/local/lib/python3.8/dist-packages/hydra/core/utils.py in <lambda>(path)
#     191     OmegaConf.register_new_resolver(
#     192         "hydra",
# --> 193         lambda path: OmegaConf.select(cast(DictConfig, HydraConfig.get()), path),
#     194         replace=True,
#     195     )
#
# /usr/local/lib/python3.8/dist-packages/hydra/core/hydra_config.py in get()
#      29         instance = HydraConfig.instance()
#      30         if instance.cfg is None:
# ---> 31             raise ValueError("HydraConfig was not set")
#      32         return instance.cfg.hydra  # type: ignore
#      33
#
# InterpolationResolutionError: ValueError raised while resolving interpolation: HydraConfig was not set
#     full_key: data_dir
#     object_type=dict
